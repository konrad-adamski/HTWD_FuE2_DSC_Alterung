# %%
import pandas as pd

# %%
from sklearn.cluster import OPTICS
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
from utils.functions_08 import plot_dsc_values_with_mean
from utils.functions_08 import analyze_clusters_with_percentages

# %% [markdown]
# ### Import der Messwerte

# %%
df_experiments = pd.read_csv("data/Experiments_2nd_Heating.csv", index_col = 0)
df_experiments
# Out:
#           0-PE-10  0-PE-11  0-PE-12  0-PE-13  0-PE-14  0-PE-15  0-PE-16  \
# Temp./°C
# -25       3.94766  3.91972  4.05790  4.13289  3.82275  4.00157  4.18087
# -24       3.95250  3.92429  4.06407  4.14106  3.82973  3.99952  4.19073
# -23       3.95307  3.92736  4.06864  4.15010  3.83740  4.01068  4.19749
# -22       3.96356  3.93813  4.07811  4.15815  3.84421  4.01827  4.20877
# -21       3.97627  3.94550  4.09258  4.17234  3.85675  4.03683  4.21752
# ...           ...      ...      ...      ...      ...      ...      ...
#  270      6.77143  6.85277  7.17616  7.23334  6.77260  7.11991  7.26021
#  271      6.78967  6.87615  7.19767  7.24583  6.79039  7.13805  7.27224
#  272      6.80702  6.89665  7.21424  7.25314  6.81041  7.15291  7.27928
#  273      6.81905  6.91947  7.22636  7.26902  6.82885  7.16673  7.29254
#  274      6.83480  6.92621  7.24669  7.28779  6.84206  7.18323  7.30845
#
#           0-PE-17  0-PE-18  0-PE-19  ...  UV-PET-59  UV-PET-6  UV-PET-60  \
# Temp./°C                             ...
# -25       3.91814  4.97739  4.22145  ...    3.95683   1.88544    4.02637
# -24       3.92699  4.99383  4.22974  ...    3.97837   1.88835    4.03066
# -23       3.93712  4.98818  4.23567  ...    3.97614   1.88846    4.05506
# -22       3.94424  5.00459  4.25181  ...    3.99298   1.87911    4.05299
# -21       3.95309  5.01714  4.25870  ...    4.01335   1.88492    4.05911
# ...           ...      ...      ...  ...        ...       ...        ...
#  270      7.18403  8.81364  7.51063  ...    7.44245   2.85871    7.61240
#  271      7.20013  8.83735  7.52670  ...    7.45806   2.86621    7.63346
#  272      7.21753  8.85928  7.54118  ...    7.47667   2.87413    7.64855
#  273      7.22875  8.88105  7.55444  ...    7.48946   2.87972    7.66672
#  274      7.24226  8.89778  7.56650  ...    7.50664   2.89165    7.68988
#
#           UV-PET-7  UV-PET-76  UV-PET-77  UV-PET-78  UV-PET-79  UV-PET-8  \
# Temp./°C
# -25        2.17032    2.98046    2.88987    3.46959    3.40215   1.70131
# -24        2.16730    2.98969    2.89599    3.47728    3.39419   1.70440
# -23        2.17359    2.99713    2.90810    3.48758    3.40015   1.71841
# -22        2.16390    3.00757    2.92446    3.49876    3.42468   1.70963
# -21        2.17059    3.01472    2.91728    3.50415    3.43563   1.71217
# ...            ...        ...        ...        ...        ...       ...
#  270       3.09266    5.56269    5.37605    6.44393    6.29337   2.52425
#  271       3.09930    5.57293    5.37883    6.45563    6.30691   2.53141
#  272       3.10573    5.58632    5.39402    6.47043    6.31307   2.53573
#  273       3.11350    5.59626    5.40875    6.48404    6.32582   2.54361
#  274       3.12478    5.60783    5.41169    6.49439    6.33276   2.55046
#
#           UV-PET-9
# Temp./°C
# -25        1.87894
# -24        1.86790
# -23        1.87305
# -22        1.87415
# -21        1.88214
# ...            ...
#  270       2.69898
#  271       2.70881
#  272       2.71216
#  273       2.71296
#  274       2.72534
#
# [300 rows x 280 columns]

# %% [markdown]
# ### Daten

# %%
file_path_data = "data/051_Data_2st_Heating_PET.csv"

df_data = pd.read_csv(file_path_data)
df_data
# Out:
#        Sample Name Name of Original DSC Measurement  Mass in mg  ∆Hm in Jg-1  \
# 0        0-PET-1_1                          0-PET-1        1.44        28.88
# 1        0-PET-1_2                          0-PET-2        1.35        30.34
# 2        0-PET-1_3                          0-PET-3        1.39        30.00
# 3        0-PET-1_4                          0-PET-4        1.28        29.29
# 4        0-PET-1_5                          0-PET-5        1.34        31.94
# ..             ...                              ...         ...          ...
# 133  3-EBT-PET-4_1                        eb-PET-62        1.18        36.62
# 134  3-EBT-PET-4_2                        eb-PET-63        1.27        36.95
# 135  3-EBT-PET-4_3                        eb-PET-64        1.30        36.87
# 136  3-EBT-PET-4_4                        eb-PET-65        1.21        36.30
# 137  3-EBT-PET-4_5                        eb-PET-66        1.15        37.02
#
#          Segment Polymer  TStart in °C  TEnd in °C  Tm in °C   Tm       Hm  \
# 0    2nd Heating     PET        200.00      253.77     230.2  230  2.99577
# 1    2nd Heating     PET        200.79      256.30     230.5  230  2.78461
# 2    2nd Heating     PET        200.00      254.25     229.8  230  3.05761
# 3    2nd Heating     PET        200.00      254.59     230.2  230  2.95315
# 4    2nd Heating     PET        200.00      255.31     229.7  230  2.76109
# ..           ...     ...           ...         ...       ...  ...      ...
# 133  2nd Heating     PET        205.46      254.29     239.9  240  6.79035
# 134  2nd Heating     PET        201.99      251.99     239.9  240  6.08880
# 135  2nd Heating     PET        202.37      251.33     240.0  240  6.31048
# 136  2nd Heating     PET        198.86      256.10     239.3  239  6.60616
# 137  2nd Heating     PET        201.98      250.86     240.2  240  6.85982
#
#     Modality  Tail   Shoulder            Aging Level
# 0    bimodal  left  undefined  Pristine LDPE and PET
# 1    bimodal  left  undefined  Pristine LDPE and PET
# 2    bimodal  left  undefined  Pristine LDPE and PET
# 3    bimodal  left  undefined  Pristine LDPE and PET
# 4    bimodal  left  undefined  Pristine LDPE and PET
# ..       ...   ...        ...                    ...
# 133     wide  left  undefined              Third EBT
# 134     wide  left  undefined              Third EBT
# 135     wide  left  undefined              Third EBT
# 136     wide  left  undefined              Third EBT
# 137     wide  left  undefined              Third EBT
#
# [138 rows x 15 columns]

# %%
df_data["Aging Level"].value_counts()
# Out:
# Aging Level
# First UV-cycle (4 weeks irradiation)     20
# Second UV-cycle (8 weeks irradiation)    20
# Third UV-cycle (12 weks irradiation)     20
# First EBT                                20
# Second EBT                               20
# Pristine LDPE and PET                    19
# Third EBT                                19
# Name: count, dtype: int64

# %%
df_data.dtypes
# Out:
# Sample Name                          object
# Name of Original DSC Measurement     object
# Mass in mg                          float64
# ∆Hm in Jg-1                         float64
# Segment                              object
# Polymer                              object
# TStart in °C                        float64
# TEnd in °C                          float64
# Tm in °C                            float64
# Tm                                    int64
# Hm                                  float64
# Modality                             object
# Tail                                 object
# Shoulder                             object
# Aging Level                          object
# dtype: object

# %% [markdown]
# ## Für '∆Hm in Jg-1', 'TStart in °C', 'TEnd in °C',  'Tm in °C', Hm, Modality

# %%
# Modality in numerische Werte umwandeln
df_data['Modality_numeric'] = df_data['Modality'].astype('category').cat.codes
df_data
# Out:
#        Sample Name Name of Original DSC Measurement  Mass in mg  ∆Hm in Jg-1  \
# 0        0-PET-1_1                          0-PET-1        1.44        28.88
# 1        0-PET-1_2                          0-PET-2        1.35        30.34
# 2        0-PET-1_3                          0-PET-3        1.39        30.00
# 3        0-PET-1_4                          0-PET-4        1.28        29.29
# 4        0-PET-1_5                          0-PET-5        1.34        31.94
# ..             ...                              ...         ...          ...
# 133  3-EBT-PET-4_1                        eb-PET-62        1.18        36.62
# 134  3-EBT-PET-4_2                        eb-PET-63        1.27        36.95
# 135  3-EBT-PET-4_3                        eb-PET-64        1.30        36.87
# 136  3-EBT-PET-4_4                        eb-PET-65        1.21        36.30
# 137  3-EBT-PET-4_5                        eb-PET-66        1.15        37.02
#
#          Segment Polymer  TStart in °C  TEnd in °C  Tm in °C   Tm       Hm  \
# 0    2nd Heating     PET        200.00      253.77     230.2  230  2.99577
# 1    2nd Heating     PET        200.79      256.30     230.5  230  2.78461
# 2    2nd Heating     PET        200.00      254.25     229.8  230  3.05761
# 3    2nd Heating     PET        200.00      254.59     230.2  230  2.95315
# 4    2nd Heating     PET        200.00      255.31     229.7  230  2.76109
# ..           ...     ...           ...         ...       ...  ...      ...
# 133  2nd Heating     PET        205.46      254.29     239.9  240  6.79035
# 134  2nd Heating     PET        201.99      251.99     239.9  240  6.08880
# 135  2nd Heating     PET        202.37      251.33     240.0  240  6.31048
# 136  2nd Heating     PET        198.86      256.10     239.3  239  6.60616
# 137  2nd Heating     PET        201.98      250.86     240.2  240  6.85982
#
#     Modality  Tail   Shoulder            Aging Level  Modality_numeric
# 0    bimodal  left  undefined  Pristine LDPE and PET                 0
# 1    bimodal  left  undefined  Pristine LDPE and PET                 0
# 2    bimodal  left  undefined  Pristine LDPE and PET                 0
# 3    bimodal  left  undefined  Pristine LDPE and PET                 0
# 4    bimodal  left  undefined  Pristine LDPE and PET                 0
# ..       ...   ...        ...                    ...               ...
# 133     wide  left  undefined              Third EBT                 2
# 134     wide  left  undefined              Third EBT                 2
# 135     wide  left  undefined              Third EBT                 2
# 136     wide  left  undefined              Third EBT                 2
# 137     wide  left  undefined              Third EBT                 2
#
# [138 rows x 16 columns]

# %%
# Merkmalsauswahl
features = ['∆Hm in Jg-1', 'TStart in °C', 'TEnd in °C', 'Tm in °C', 'Hm', 'Modality_numeric']
X = df_data[features]

# Entfernen von NaN-Werten (falls vorhanden)
X = X.dropna()

# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# OPTICS Clustering
optics_model = OPTICS(min_samples=4, xi=0.05, min_cluster_size=10)
clusters = optics_model.fit_predict(X_scaled)

# Ergebnisse in den DataFrame hinzufügen
df_data = df_data.loc[X.index]  # Reihen anpassen
df_data['Cluster'] = clusters

# %%
# Scatterplot der Clusterergebnisse
plt.figure(figsize=(10, 6))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='rainbow', alpha=0.7, edgecolors='k')
plt.title('OPTICS Clustering Results')
plt.xlabel('Feature 1 (scaled)')
plt.ylabel('Feature 2 (scaled)')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
cluster_dict = df_data.groupby("Cluster")["Name of Original DSC Measurement"].apply(list).to_dict()

# %%
for cluster, samples in cluster_dict.items():
    # Filtere gültige Samples
    valid_samples = [sample for sample in samples if sample in df_experiments.columns]

    # Plot nur für gültige Samples
    if valid_samples:
        title = f"DSC Measurement Values - Cluster {cluster}"
        plot_dsc_values_with_mean(df_experiments, valid_samples, title=title)

        # Filter df_data nach valid_samples und berechne value_counts für "Aging Level"
        #filtered_df = df_data[df_data["Name of Original DSC Measurement"].isin(valid_samples)]

        #aging_level_counts = filtered_df["Aging Level"].value_counts()
        #print(aging_level_counts)
        #print("---" * 40)
        
        filtered_df = df_data[df_data["Name of Original DSC Measurement"].isin(samples)]
        aging_level_counts = filtered_df["Aging Level"].value_counts()
        print(aging_level_counts)
        print("---" * 40)
           
        
        
    else:
        print(f"No valid samples found for Cluster {cluster}.")
# Out:
# Aging Level
# Pristine LDPE and PET                    9
# First UV-cycle (4 weeks irradiation)     8
# Second UV-cycle (8 weeks irradiation)    3
# Name: count, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# Aging Level
# Third UV-cycle (12 weks irradiation)     20
# First EBT                                20
# Second EBT                               20
# First UV-cycle (4 weeks irradiation)      2
# Second UV-cycle (8 weeks irradiation)     2
# Name: count, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# Aging Level
# Second UV-cycle (8 weeks irradiation)    10
# Name: count, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# Aging Level
# First UV-cycle (4 weeks irradiation)     10
# Second UV-cycle (8 weeks irradiation)     5
# Name: count, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# Aging Level
# Pristine LDPE and PET    10
# Name: count, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# Aging Level
# Third EBT    19
# Name: count, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
